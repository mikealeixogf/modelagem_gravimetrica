# %% [markdown]
# <a href="https://colab.research.google.com/github/mikealeixogf/modelagem_gravimetrica/blob/main/Anomalia_prisma_Pallero_Talwani_Nettleton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # A anomalia gravimetrica Talwani et. al 1960
#
# $$gz = 2 G \rho \sum_{i=1}^n Z_i$$
# $$$$
#
#
# $$Z_i = a_{i} sin\phi_{i} cos\phi_{i} \left[ \theta_{i} - \theta_{i+1} + tan\phi_{i} ln \dfrac{cos\theta_{i}(tan\theta_{i} - tan\phi_{i})}{cos\theta_{i+1}(tan\theta_{i+1} - tan\phi_{i})}\right]$$
#
#
#
# \
#
# $$X_i = a_{i} sin\phi_{i} cos\phi_{i} \left[ tan\phi_i(\theta_{i+1} - \theta_{i}) + ln \dfrac{cos\theta_{i}(tan\theta_{i} - tan\phi_{i})}{cos\theta_{i+1}(tan\theta_{i+1} - tan\phi_{i})}\right]$$
# \
# $$\text{onde}$$
# \
# $$\theta_{i} = tan^{-1} \dfrac{z_i}{x_i}$$
# \
# $$\phi_{i} = tan^{-1} \dfrac{z_{i+1} -z_i}{x_{i+1} - x_i}$$
# \
# $$\theta_{i} = tan^{-1} \dfrac{z_{i+1}}{x_{i+1}}$$
# \
#   $$\text{e}$$
#   \
#   $$a_{i} = x_{i+1} + z_{i+1} \dfrac{x_{i+1} - x_i}{z_{i} - z_{i+1} }$$
#
#   ## Caso A
#
#   $$\text{se} \ \ \ \ x_i = 0 $$
# $$Z_i= - a_{i} sin\phi_{i} cos\phi_{i} \left[ \theta_{i+1} - \dfrac{\pi}{2} + tan\phi_{i} \ln (cos\theta_{i+1}(tan\theta_{i+1} - tan\phi_{i}))\right]$$
#
#
# $$X_i= a_{i} sin\phi_{i} cos\phi_{i} \left[ tan\phi_i(\theta_{i+1} - \dfrac{\pi}{2}) +  \ln (cos\theta_{i+1}(tan\theta_{i+1} - tan\phi_{i}))\right]$$
#
# ## Caso B
#
# $$\text{se} \ \ \ \ x_{i+1} = 0 $$
# $$Z_i= a_{i} sin\phi_{i} cos\phi_{i} \left[ \theta_{i} - \dfrac{\pi}{2} + tan\phi_{i} \ln (cos\theta_{i}(tan\theta_{i} - tan\phi_{i}))\right]$$
#
#
#  $$X_i= - a_{i} sin\phi_{i} cos\phi_{i} \left[ tan\phi_i(\theta_{i} - \dfrac{\pi}{2}) +  \ln (cos\theta_{i}(tan\theta_{i} - tan\phi_{i}))\right]$$
# ##Caso C
# $$\text{se} \ \ \ \ z_i = z_{i+1} $$
#
# $$Z_i = z_i(\theta_{i+1} - \theta_i$$
# $$X_i = z_i \ln{\dfrac{sin\theta_{i+1}}{sin\theta_i}}$$
# ## Caso D
#
# $$\text{se} \ \ \ \ x_i = x_{i+1} $$
#
# $$Z_i = x_i \ln{\dfrac{cos\theta_{i}}{cos\theta_{i+1}}}$$
# $$X_i =x_i(\theta_{i+1} - \theta_i) $$
#
#
# # Caso E
# $$\text{se} \ \ \ \ \theta_i = \theta_{i+1} $$
#
# $$Z_i = 0$$
# $$X_i = 0$$
#
# ## Caso F
#
# $$\text{se} \ \ \ \ x_i = z_{i}=0 $$
# $$Z_i = 0$$
# $$X_i = 0$$
#
# ## Caso G
#
# $$\text{se} \ \ \ \ x_{i+1} = z_{i+1}=0 $$
# $$Z_i = 0$$
# $$X_i = 0$$

# %% [markdown]
# #Anomalia Gravimétrica computada por Pallero 2015, Telford et. al. 1975.
#
#
#
# $$\textbf{g} \equiv \text{g}_j =\gamma \Delta \rho \left[ A \ln \left( \frac{A^2 + D^2}{A^2 + C^2} \right) - B \ln \left( \frac{B^2 + D^2}{B^2 + C^2} \right) - 2C \left( \arctan \left( \frac{A}{C} \right) - \arctan \left( \frac{B}{C} \right) \right) + 2D \left( \arctan \left( \frac{A}{D} \right) - \arctan \left( \frac{B}{D} \right) \right) \right]$$
#
#    $$A = x_p - x_1$$
#    $$B = x_p - x_2 $$
#   $$C = z_1 $$
#    $$D = z_2 $$

# %% [markdown]
# #Anomalia Gravimétrica computada por um conjunto de fitas Nettleton (1940)
# $$g_{ij} = 2\gamma \Delta\rho\delta_{ij}t$$
# em que
# $$\delta_{ij}=\delta(x_i,x_j,d_j(x_i)) = atan \left(\dfrac{-\Delta x (d_j(x_I) -t/2) }{(d_j(x_i)-t/2)^2 + (x_j - \Delta x /2 - x_i)(x_j + \Delta x /2 - x_i)}\right)$$

# %%
#CALCULO PARA ANOMALIA GRAVIMÉTRICA DE UM ÚNICO PRISMA
import numpy as np
import matplotlib.pyplot as plt

#input
gamma= 6.67 #é a constnte gravitacional
xi=np.linspace(0,30,60) #é a extensão de observação e espaçamento entre as observações

xj= 15 # é o centro do prisma, que é a profundidade.
dj= 0.05 # é a profundidade do prisma
dx= 3 # é a extensão do prisma
t= 2.01 # é a espessura do prisma
deltarho= 0.3 # é o contraste de densidade
v=dx/2 # apenas para facilitar o calculo
l=t/2 #APENAS PARA FACILITAR O CÁLCULO
#equação do prisma
x1=xj-v;
x2=xj+v;
A=xi-x1;
B=xi-x2;
C= dj;
D= dj+t;
gprisma = gamma*deltarho*(A*np.log((A**2+D**2)/(A**2+C**2)) -
                          B*np.log((B**2+D**2)/ (B**2+C**2))-
                          2*C*(np.arctan(A/C)-np.arctan(B/C))+
                          2*D*(np.arctan(A/D)-np.arctan(B/D)))
#print(gprisma)

numerador = -dx*(dj-l)
denominador = (dj-l)**2 + (xj-v-xi)*(xj+v-xi)
delta = (np.arctan2(numerador, denominador))
gfita=2*gamma*delta*deltarho*t

#Dimensões do Prisma
x3=xj+ (dx/2); # ""         do teceiro "           "
x4=xj- (dx/2); # "           do quarto "           "
x0=xj- (dx/2); # Corecao manual para completar a figura
z1=dj;         # Profundidade de um dos vertices da fita em fumcao de x
z2=dj;
z3=dj+t;
z4=z3;
z0=dj;

hozA=[x1, x2,x3,x4,x0];   #Preparação para plotagem
profB=[z1, z2, z3, z4, z0];

#Plot de figura
plt.figure(figsize=(15,7))
plt.subplot(2,1,1)#duas linhas, uma coluna, posição 1
plt.plot(xi,gprisma,'-', color='r', linewidth= 2,label='Anomalia Prisma')
plt.plot(xi,gfita,':', color='b',linewidth=2, label='Anomalia Fita')
plt.xlim(0,30)
plt.ylabel('Anomalia (mGal)')
#plt.xlabel('extensão horizontal (km)')
plt.legend()
#_______________________________________________________________________________

plt.subplot(2,1,2)#duas linhas, uma coluna, posição 2
plt.fill(hozA,profB, color='gray', alpha=0.5, edgecolor='black')
plt.ylim(0,5)
plt.xlim(0,30)
plt.gca().invert_yaxis() #comando que invert os eixos.
plt.ylabel('Profundidade (km)')
plt.xlabel('Extensão horizontal (km)')
plt.legend(['Dimensão: prisma unitário = fita'])
plt.show() #apresenta a imagem na tela

# %%
#CALCULO ANOMALIA GRAVIMÉTRICA TALWANI ET AL (1959)

import numpy as np
import matplotlib.pyplot as plt

# Função para carregar dados de um arquivo txt
def carregar_dados(arquivo):
    return np.loadtxt(arquivo)

# Função de cálculo da anomalia gravitacional de Talwani
def talwani_gravity(density_contrast, n_sides, n_stat, x_start, z_start, x_obs, z_obs):
    gamma = 6.67259  # Constante gravitacional em unidades do SI (m³⋅kg⁻¹⋅s⁻²)
    gz = np.zeros(n_stat, dtype=np.float64)  # Inicializando o vetor de anomalia com precisão dupla

    # Alocar memória com precisão
    x = np.zeros(n_sides + 1, dtype=np.float64)
    z = np.zeros(n_sides + 1, dtype=np.float64)

    # Função para determinar o sinal do polígono (usada no Talwani)
    def lusense(nv, xv, zv):
        area = 0.0
        eps = 1.E-05
        for j in range(1, nv - 1):
            area += (xv[j] - xv[0]) * (zv[j + 1] - zv[0]) - (xv[j + 1] - xv[0]) * (zv[j] - zv[0])
        if abs(area) <= eps:
            print("Polígono muito fino!")
        return np.sign(area)

    isign = lusense(n_sides, x_start, z_start)
    pi = np.pi
    ct = isign * 2 * gamma * density_contrast

    for n in range(n_stat):
        gz[n] = 0.0
        for i in range(n_sides):
            z[i] = z_start[i] + z_obs
            x[i] = x_start[i] - x_obs[n]

        z[n_sides] = z[0]
        x[n_sides] = x[0]

        for i in range(n_sides):
            if x[i] == 0.0 and z[i] == 0.0:
                z[i] = 1E-10  # Evitar divisão por zero
            diffz = z[i + 1] - z[i]
            diffx = x[i + 1] - x[i]
            diffz2 = diffz * diffz
            diffx2 = diffx * diffx
            if z[i] == 0.0 and x[i] == 0.0:
                theta = 0.0
            else:
                theta = np.arctan2(z[i], x[i])

            if z[i + 1] == 0.0 and x[i + 1] == 0.0:
                theta1 = 0.0
            else:
                theta1 = np.arctan2(z[i + 1], x[i + 1])

            d = theta - theta1
            if d > pi:
                diffth = d - 2.0 * pi
            elif d < -pi:
                diffth = d + 2.0 * pi
            else:
                diffth = d

            a = (x[i] * z[i + 1] - z[i] * x[i + 1]) / (diffz2 + diffx2)
            b = diffx * diffth
            c = (x[i + 1]**2 + z[i + 1]**2) / (x[i]**2 + z[i]**2)
            if c == 0.0:
                d = 0.0
            else:
                d = 0.5 * diffz * np.log(c)

            delg = a * (b + d)
            gz[n] += ct * delg

    return gz

# Carregar dados do arquivo de texto
dados = carregar_dados('/content/drive/MyDrive/RELEVO_VERD.TXT')

# Extraindo x e z das observações
x_start = dados[:, 0]  # Primeira coluna (x)
z_start = dados[:, 1]  # Segunda coluna (z)

# Parâmetros de entrada
density_contrast = -0.3  # Contraste de densidade (g/cm³)
n_sides = len(x_start) - 1
n_stat = 60  # Número fixo de observações (alterado diretamente aqui)
x_obs = np.linspace(min(x_start), max(x_start), n_stat)  # Distribuir as observações uniformemente no intervalo de x_start
z_obs = 0.005  # Altitude comum das estações

# Calcular a anomalia
gz = talwani_gravity(density_contrast, n_sides, n_stat, x_start, z_start, x_obs, z_obs)

# Exibir resultados
#print(gz)

# Plotando os gráficos
fig = plt.figure(figsize=(15,7))

plt.subplot(2, 1, 1)  # duas linhas, uma coluna, posição 1
plt.plot(x_obs, gz, 'o', color='black')
plt.xlim(0, 60)
plt.ylabel('Anomalia (mGal)')
plt.legend(['Anomalia'])

plt.subplot(2, 1, 2)  # duas linhas, uma coluna, posição 2
plt.fill(x_start, z_start,color='black', alpha=0.3, edgecolor='black', linewidth=1)
plt.ylim(0, 2.1)
plt.xlim(0, 60)
plt.gca().invert_yaxis()  # Inverter o eixo Y para profundidade crescente para baixo
plt.ylabel('Profundidade (km)')
plt.xlabel('Extensão horizontal (km)')
plt.legend(['Vértices do polígono'])

plt.show()

# %%
#ANOMALIA GRAVIMÉTRICA PRISMA, PALERO (2015), TELFORD ET AL (1975)

import numpy as np
import matplotlib.pyplot as plt

#CRIANDO FUNÇÕES
#FUNÇÃO DE CARREGAMENTO DOS DADOS EM ARQUIVO TXT
def carregar_dados(arquivo):
  return np.loadtxt(arquivo)

#FUNÇÃO CÁLCULO DE ANOMALIA GRAVIMÉTRICA

def anomalia_grav(dados, gamma, deltarho,xi,dj,dx):
  xj= dados[:,0] # é o centro do prisma, que é a profundidade.
  t= dados[:,1]
  gprisma=0
  for i in range(len(xj)):
    v=dx/2
    x1=xj[i]-v
    x2=xj[i]+v;
    A=xi-x1;
    B=xi-x2;
    C= dj;
    D= dj+t[i];
    gprisma += gamma*deltarho*(A*np.log((A**2+D**2)/(A**2+C**2)) -
                             B*np.log((B**2+D**2)/ (B**2+C**2))-
                             2*C*(np.arctan(A/C)-np.arctan(B/C))+
                             2*D*(np.arctan(A/D)-np.arctan(B/D)))
  return gprisma

#FUNÇÃO CÁLCULO DOS VÉRTICES DOS PRISMAS

def vertices(dados,dj,dx):
  listah=[]
  listaz=[]
  xj= dados[:,0] # é o centro do prisma, que é a profundidade.
  t= dados[:,1]
#Dimensões do Prisma
  for i in range(len(xj)):
    v=dx/2
    x1=xj[i]- v; # Coordenada do primeiro vertice; em função de x
    x2=xj[i]+ v; # Cooedenada do segundo vertice; em função de x
    x3=xj[i]+ v; # ""         do teceiro "           "
    x4=xj[i]- v; # "           do quarto "           "
    h=[x1,x2,x3,x4,x1]
    listah.append(h)

  for j in range(len(t)):
    z1=dj;         # Profundidade de um dos vertices da fita em fumcao de x
    z2=dj;
    z3=dj+t[j];
    z4=z3;
    z=[z1,z2,z3,z4,z1]
    listaz.append(z)
  return listah, listaz


def plotar_resultados(xi, gprisma, listah, listaz):
    plt.figure(figsize=(15, 7))

    plt.subplot(2, 1, 1)
    plt.plot(xi, gprisma, 'o', color='b')
    plt.xlim(0, 60)
    plt.ylabel('Anomalia (mGal)')
    plt.legend(['Anomalia'])

    plt.subplot(2, 1, 2)
    for i in range(len(listah)):
        plt.fill(listah[i], listaz[i], color='blue',alpha=0.5,edgecolor='black', linewidth=1)
    plt.ylim(0, 2.1)
    plt.xlim(0, 60)
    plt.gca().invert_yaxis()
    plt.ylabel('Profundidade (km)')
    plt.xlabel('Extensão horizontal (km)')
    plt.legend(['Prismas verticais justapostos'])

    plt.show()

gamma= 6.67259 #é a constnte gravitacional
xi=np.linspace(0,60,60) #é a extensão de observação e espaçamento entre as observações
dx= 0.5 # é a extensão do prisma
dj= 0.001 #é a profundidade do prisma
deltarho= -0.3 # é o contraste de densidade

dados=carregar_dados('/content/drive/MyDrive/RELEVO_VERD.TXT')
gprisma=anomalia_grav(dados,gamma,deltarho,xi,dj,dx)
#print(gprisma)
listah,listaz=vertices(dados,dj,dx)
plotar_resultados(xi,gprisma,listah,listaz)

# %%
#ANOMALIA GRAVIMÉTRICA FITA, NETTLETON (1940)

import numpy as np
import matplotlib.pyplot as plt

#CRIANDO FUNÇÕES
#FUNÇÃO DE CARREGAMENTO DOS DADOS EM ARQUIVO TXT
def carregar_dados(arquivo):
  return np.loadtxt(arquivo)

#FUNÇÃO CÁLCULO DE ANOMALIA GRAVIMÉTRICA UTILIZANDO GFITA NETTLETON, 1940

def anomalia_fita(dados,gamma,deltarho,xi,dj,dx):
  xj= dados[:,0] # é o centro do prisma, que é a profundidade.
  t= dados[:,1]
  gfita=0
  for i in range(len(xj)):
    v=dx/2
    l=t[i]/2
    numerador = -dx*(dj-l)
    denominador = (dj-l)**2 + (xj[i]-v-xi)*(xj[i]+v-xi)
    delta = (np.arctan2(numerador, denominador))
    gfita+=2*gamma*delta*deltarho*t[i]
  return gfita

#FUNÇÃO CÁLCULO DOS VÉRTICES DAS FITAS

def vertices(dados,dj,dx):
  listah=[]
  listaz=[]
  xj= dados[:,0] # é o centro do prisma, que é a profundidade.
  t= dados[:,1]
#Dimensões do Prisma
  for i in range(len(xj)):
    v=dx/2
    x1=xj[i]- v; # Coordenada do primeiro vertice; em função de x
    x2=xj[i]+ v; # Cooedenada do segundo vertice; em função de x
    x3=xj[i]+ v; # ""         do teceiro "           "
    x4=xj[i]- v; # "           do quarto "           "
    h=[x1,x2,x3,x4,x1]
    listah.append(h)

  for j in range(len(t)):
    z1=dj;         # Profundidade de um dos vertices da fita em fumcao de x
    z2=dj;
    z3=dj+t[j];
    z4=z3;
    z=[z1,z2,z3,z4,z1]
    listaz.append(z)
  return listah, listaz


def plotar_resultados(xi, gprisma, listah, listaz):
    plt.figure(figsize=(15, 7))
    plt.subplot(2, 1, 1)
    plt.plot(xi, gprisma, 'o', color='g')
    plt.xlim(0, 60)
    plt.ylabel('Anomalia (mGal)')
    plt.legend(['Anomalia'])

    plt.subplot(2, 1, 2)
    for i in range(len(listah)):
        plt.fill(listah[i], listaz[i], color='g',alpha=0.5,edgecolor='black', linewidth=1)
    plt.ylim(0, 2.1)
    plt.xlim(0, 60)
    plt.gca().invert_yaxis()
    plt.ylabel('Profundidade (km)')
    plt.xlabel('Extensão horizontal (km)')
    plt.legend(['Fitas justapostas'])
    plt.show()

gamma= 6.67259 #é a constnte gravitacional
xi=np.linspace(0,60,60) #é a extensão de observação e espaçamento entre as observações
dx= 0.5 # é a extensão do prisma
dj= 0.001 #é a profundidade do prisma
deltarho= -0.3 # é o contraste de densidade

dados=carregar_dados('/content/drive/MyDrive/RELEVO_VERD.TXT')
listah,listaz=vertices(dados,dj,dx)
gfita=anomalia_fita(dados,gamma,deltarho,xi,dj,dx)
#print(gfita)
plotar_resultados(xi,gfita,listah,listaz)

# %%
import numpy as np
import matplotlib.pyplot as plt
# Plotando os gráficos
fig = plt.figure(figsize=(15,7))

plt.subplot(2, 1, 1)  # duas linhas, uma coluna, posição 1
plt.plot(x_obs, gz, color='red',alpha=0.8,linewidth=3,label='Polígono')
plt.plot(xi,gprisma,'--',color='b',alpha=1,linewidth=2, label='Prisma')
plt.plot(xi,gfita,color='green',alpha=1, linewidth=1.6, label='Fita')
plt.xlim(0, 60)
plt.ylabel('Anomalia (mGal)')
plt.legend()

plt.subplot(2, 1, 2)  # duas linhas, uma coluna, posição 2
plt.fill(x_start, z_start,color='red', alpha=0.3, edgecolor='black', linewidth=1)
plt.ylim(0, 2.1)
plt.xlim(0, 60)
plt.gca().invert_yaxis()  # Inverter o eixo Y para profundidade crescente para baixo
plt.ylabel('Profundidade (km)')
plt.xlabel('Extensão horizontal (km)')
plt.legend(['Bacia Sedimentar'])
plt.show()

# %%
#Cálculo do RMSE (REMEQ) Raiz quadrada do erro médio quadrático

import numpy as np

# Valores observados (reais) e calculados
poligono = np.array(gz)
prisma = np.array(gprisma)
fita=np.array(gfita)

# Cálculo do RMSE
rmse_poligono_prisma = np.sqrt(np.mean((poligono - prisma)**2))
rmse_poligono_fita = np.sqrt(np.mean((poligono - fita)**2))
rmse_prisma_fita = np.sqrt(np.mean((prisma - fita)**2))
print(f'RMSE entre Polígono e Prisma: {rmse_poligono_prisma}')
print(f'RMSE entre Polígono e Fita: {rmse_poligono_fita}')
print(f'RMSE entre Prisma e Fita: {rmse_prisma_fita}')

#Calculo Erro Relativo Percentual
erp_poligono_prisma=np.abs((poligono-prisma)/poligono*100)
erp_poligono_fita=np.abs((poligono-fita)/poligono*100)
erp_prisma_fita=np.abs((prisma-fita)/prisma*100)

fig = plt.figure(figsize=(15,5))
plt.plot(erp_poligono_prisma,color='red', alpha=1, linewidth=2,label='Polígono_prisma')
plt.plot(erp_poligono_fita, color='blue', alpha=1, linewidth=2,label='Polígono_fita')
plt.plot(erp_prisma_fita,color='green', alpha=1, linewidth=2, label='Prisma_fita')
plt.xlim(-1, 60)
#plt.ylim(0,9)
plt.ylabel('Erro relativo (%)')
plt.legend()
plt.show()
# Out:
# RMSE entre Polígono e Prisma: 0.11696791169038905
# RMSE entre Polígono e Fita: 0.24246332193354414
# RMSE entre Prisma e Fita: 0.21586140221167735

# %% [markdown]
# OBSERVAÇÃO 1: O RMSE É DIFERENTE PARA AS ANOMALIAS CALCULADAS PARA O MESMO PONTO, MESMAS PROFUNDIDADES COM OS MESMOS MÉTODOS, DEVIDO A LINGUAGEM DE PROGRAMAÇÃO SER DIFERENTE DA LINGUAGEM FORTRAN, QUE É MUITO MELHOR PARA FAZER CÁLCULOS NÚMERICOS
#
#
#
# OBSERVAÇÃO 2: OBSERVAÇÃO IMPORTANTE É QUE OS PICOS VIZUALISADOS NO CÁLCULO DO ERRO RELATIVO PERCENTUAL ESTÃO PRÓXIMOS ÀS REGIÕES ONDE HÁ DESCONITÍNUIDDADE ABRUPTA DO RELEVO DO EMBASAMENTO.
#
# OBSERVAÇÃO 3: SE MUDAR LEVEMENTE OS PARÂMETROS DE PROFUNDIDADE, OS CÁLCULOS DO MODELO REFERENTES A ANOMALIA CALCULADA, RMSE E ERRO RELATIVO ABSOLUTO, SÃO TOTALMENTE DIFERENTES DE UM MODELO COM O VALOR ADJACENTE MAIS SUAVE.
